# %% [markdown]
# # Week 2 Mini project
# ## Predicting copper future price

# %% [markdown]
# ### 1. Background

# %% [markdown]
# A copper future is a legally binding agreement to buy or sell a standard quantity of Grade-A cathode copper at a preset price for delivery (or cash‐settlement) on a future date. Producers hedge price risk, manufacturers lock-in costs, and speculators trade anticipated moves.
#
# There are three major future exchanges that trade copper contracts, namely, Shanghai Futures Exchange (CU), London metal exchange (CA), and CME Group / COMEX Copper (HG). Copper contracts in the three exchanges often share similar prices but are almost never identical. This is because the three markets operate in different time, and are technically selling copper contrasts in different countries. A brief summary of the differences across the three exchanges can be found at the end of this document.
#
# In this project, we will try to leverage the three exchange markets as well as the abudant data on the Internet to build a predictive model for U.S. copper contract prices.

# %% [markdown]
# > In a recent announcement, a $50\%$ tariff will be imposed on imported copper to U.S., which should drive up the U.S. copper contract price. However, according to [a news piece](https://www.reuters.com/markets/commodities/trumps-copper-tariffs-wont-lift-us-output-will-boost-costs-2025-07-10/) by Reuters: "U.S. copper contracts rose to a 26% premium over their London equivalent on Wednesday from a 13% premium before Trump's announcement. That 26% premium is still well short of the 50% tariff, likely indicating the uncertainty in the market as to what types of copper products will be subject to tariffs or the risk of a lower rate for some countries."

# %% [markdown]
# ### 2. Objective

# %% [markdown]
# The grand objective is simple: to build a model to predict the U.S. copper contracts price per day. You are free to fit any models or use any data you can find, as long as the model uses only data before the market opens on the day of interest (i.e., no data leakage).
#
# To get started, you can run the following cells to download the copper contract prices from the three exchanges. You might need to install some libraries if you see errors complaining on libraries found.

# %%
# %pip install yfinance
import yfinance as yf
import pandas as pd

# ------------------------------------------------------------
# 1.  Download daily front-month copper futures (COMEX)
# ------------------------------------------------------------
ticker = "HG=F"                # Copper continuous contract on Yahoo Finance
start  = "2010-01-01"          # any start date you like
end    = "2025-07-15"          # or leave end=None for “today”

NY = yf.download(ticker, start=start, end=end, interval="1d")

# Quick sanity-check
NY.head()
# Out:
# Requirement already satisfied: yfinance in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (0.2.65)
# Requirement already satisfied: pandas>=1.3.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yfinance) (2.3.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: requests>=2.31 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yfinance) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yfinance) (4.13.4)
# Requirement already satisfied: curl_cffi>=0.7 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yfinance) (0.12.0)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yfinance) (5.28.3)
# Requirement already satisfied: websockets>=13.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.14.1)
# Requirement already satisfied: cffi>=1.12.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (2025.7.14)
# Requirement already satisfied: pycparser in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# /var/folders/x8/r3trhgk10jz0y69mhxk1mpd00000gn/T/ipykernel_72579/1926688803.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   NY = yf.download(ticker, start=start, end=end, interval="1d")
# [*********************100%***********************]  1 of 1 completed
# Price        Close    High     Low    Open Volume
# Ticker        HG=F    HG=F    HG=F    HG=F   HG=F
# Date
# 2010-01-04  3.3880  3.4090  3.3530  3.3880    404
# 2010-01-05  3.3960  3.4110  3.3685  3.3960    242
# 2010-01-06  3.4775  3.4995  3.4335  3.4775    109
# 2010-01-07  3.4115  3.5235  3.4110  3.4995    326
# 2010-01-08  3.3880  3.4220  3.3800  3.3880    311

# %%
NY.tail()
NY['High'].info()
NY
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3905 entries, 2010-01-04 to 2025-07-14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HG=F    3905 non-null   float64
# dtypes: float64(1)
# memory usage: 61.0 KB
# Price        Close    High     Low    Open Volume
# Ticker        HG=F    HG=F    HG=F    HG=F   HG=F
# Date
# 2010-01-04  3.3880  3.4090  3.3530  3.3880    404
# 2010-01-05  3.3960  3.4110  3.3685  3.3960    242
# 2010-01-06  3.4775  3.4995  3.4335  3.4775    109
# 2010-01-07  3.4115  3.5235  3.4110  3.4995    326
# 2010-01-08  3.3880  3.4220  3.3800  3.3880    311
# ...            ...     ...     ...     ...    ...
# 2025-07-08  5.6450  5.6450  4.9495  4.9680    922
# 2025-07-09  5.4435  5.6820  5.3975  5.4670    857
# 2025-07-10  5.5480  5.5930  5.5435  5.5800    756
# 2025-07-11  5.5620  5.5850  5.4500  5.5850   1082
# 2025-07-14  5.5150  5.5150  5.4495  5.4760   1093
#
# [3905 rows x 5 columns]

# %%
# %pip install akshare
# %pip install pandas_datareader

import akshare as ak
import datetime as dt
from pandas_datareader import data as web

MT_TO_LB = 2204.62262    
# main (dominant) copper contract from Sina Finance, date index ascending
SHFE = ak.futures_main_sina(symbol="CU0",end_date="20250715",start_date="20150101")   # "CU0" -> SHFE copper continuous
# rename to English
SHFE = SHFE.rename(columns={
    "日期": "date",
    "开盘价": "open",
    "最高价": "high",
    "最低价": "low",
    "收盘价": "close",
    "成交量": "volume",
    "持仓量": "open_interest",
    "动态结算价": "settlement_price"
})
# ---- FX: CNY per USD (daily) --------------------------------
fx = (
    web.DataReader(
        "DEXCHUS",      # Yuan per 1 USD (FRED)
        "fred",
        2005,
        2025  # or leave end=None for “today”
    )
    .rename(columns={"DEXCHUS": "cny_per_usd"})
    .ffill()                        # forward-fill weekends / holidays
)

# ---- merge & convert ----------------------------------------
SHFE.set_index("date", inplace=True)        # make 'date' the index
SHFE.sort_index(inplace=True)               # (optional) keep rows in chrono order

SHFE = SHFE.join(fx, how="left")
SHFE["usd_per_ton"] = SHFE["close"] / SHFE["cny_per_usd"]
SHFE["usd_per_lb"]  = SHFE["usd_per_ton"] / MT_TO_LB

SHFE.head()
# Out:
# Requirement already satisfied: akshare in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (1.17.26)
# Requirement already satisfied: aiohttp>=3.11.13 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (3.12.15)
# Requirement already satisfied: beautifulsoup4>=4.9.1 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (4.13.4)
# Requirement already satisfied: lxml>=4.2.1 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (6.0.0)
# Requirement already satisfied: pandas>=0.25 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (2.3.1)
# Requirement already satisfied: requests>=2.22.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (2.32.4)
# Requirement already satisfied: html5lib>=1.0.1 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (1.1)
# Requirement already satisfied: xlrd>=1.2.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (2.0.2)
# Requirement already satisfied: urllib3>=1.25.8 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (2.5.0)
# Requirement already satisfied: tqdm>=4.43.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (4.67.1)
# Requirement already satisfied: openpyxl>=3.0.3 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (3.1.5)
# Requirement already satisfied: jsonpath>=0.82 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (0.82.2)
# Requirement already satisfied: tabulate>=0.8.6 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (0.9.0)
# Requirement already satisfied: decorator>=4.4.2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (5.2.1)
# Requirement already satisfied: nest_asyncio>=1.6.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (1.6.0)
# Requirement already satisfied: mini-racer>=0.12.4 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from akshare) (0.12.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from aiohttp>=3.11.13->akshare) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from aiohttp>=3.11.13->akshare) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from aiohttp>=3.11.13->akshare) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from aiohttp>=3.11.13->akshare) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from aiohttp>=3.11.13->akshare) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from aiohttp>=3.11.13->akshare) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from aiohttp>=3.11.13->akshare) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.11.13->akshare) (3.10)
# Requirement already satisfied: typing-extensions>=4.2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from aiosignal>=1.4.0->aiohttp>=3.11.13->akshare) (4.14.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from beautifulsoup4>=4.9.1->akshare) (2.7)
# Requirement already satisfied: six>=1.9 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from html5lib>=1.0.1->akshare) (1.17.0)
# Requirement already satisfied: webencodings in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from html5lib>=1.0.1->akshare) (0.5.1)
# Requirement already satisfied: et-xmlfile in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from openpyxl>=3.0.3->akshare) (2.0.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.25->akshare) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.25->akshare) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.25->akshare) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.25->akshare) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.22.0->akshare) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.22.0->akshare) (2025.7.14)
# Requirement already satisfied: six>=1.9 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from html5lib>=1.0.1->akshare) (1.17.0)
# Requirement already satisfied: webencodings in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from html5lib>=1.0.1->akshare) (0.5.1)
# Requirement already satisfied: et-xmlfile in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from openpyxl>=3.0.3->akshare) (2.0.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.25->akshare) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.25->akshare) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.25->akshare) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.25->akshare) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.22.0->akshare) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.22.0->akshare) (2025.7.14)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas_datareader in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (0.10.0)
# Requirement already satisfied: lxml in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas_datareader) (6.0.0)
# Requirement already satisfied: pandas>=0.23 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas_datareader) (2.3.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas_datareader) (2.32.4)
# Requirement already satisfied: numpy>=1.26.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.23->pandas_datareader) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.23->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: pandas_datareader in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (0.10.0)
# Requirement already satisfied: lxml in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas_datareader) (6.0.0)
# Requirement already satisfied: pandas>=0.23 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas_datareader) (2.3.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas_datareader) (2.32.4)
# Requirement already satisfied: numpy>=1.26.0 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.23->pandas_datareader) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.23->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.19.0->pandas_datareader) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.19.0->pandas_datareader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.19.0->pandas_datareader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.19.0->pandas_datareader) (2025.7.14)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.19.0->pandas_datareader) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.19.0->pandas_datareader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.19.0->pandas_datareader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages (from requests>=2.19.0->pandas_datareader) (2025.7.14)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
#              open   high    low  close  volume  open_interest  \
# date
# 2015-01-05  45500  45570  44990  45080  189194         325160
# 2015-01-06  44210  44910  43980  44800  447986         310542
# 2015-01-07  44640  44840  44420  44650  317816         301058
# 2015-01-08  44650  44890  44580  44680  208524         297932
# 2015-01-09  45000  45050  44250  44250  384066         308602
#
#             settlement_price  cny_per_usd  usd_per_ton  usd_per_lb
# date
# 2015-01-05             45250       6.2201  7247.471906    3.287398
# 2015-01-06             44570       6.2125  7211.267606    3.270976
# 2015-01-07             44660       6.2127  7186.891368    3.259919
# 2015-01-08             44740       6.2143  7189.868529    3.261270
# 2015-01-09             44550       6.2085  7127.325441    3.232900

# %%
SHFE.tail()
# Out:
#              open   high    low  close  volume  open_interest  \
# date
# 2025-07-09  79590  80170  78270  78400  162594         193999
# 2025-07-10  78340  78680  78160  78600   99231         181068
# 2025-07-11  78700  78810  78370  78430   81666         178678
# 2025-07-14  78040  78520  78010  78400   79133         172200
# 2025-07-15  77900  78160  77700  78090   81646         169903
#
#             settlement_price  cny_per_usd  usd_per_ton  usd_per_lb
# date
# 2025-07-09             78910          NaN          NaN         NaN
# 2025-07-10             78390          NaN          NaN         NaN
# 2025-07-11             78530          NaN          NaN         NaN
# 2025-07-14             78290          NaN          NaN         NaN
# 2025-07-15             77930          NaN          NaN         NaN

# %%
# The LME copper price is available MONTHLY from the IMF database
start = dt.datetime(1990, 1, 1)
LME= web.DataReader("PCOPPUSDM", "fred", start)   # IMF / LME cash price

LME.rename(columns={"PCOPPUSDM": "usd_per_ton"}, inplace=True)
LME["usd_per_lb"] = LME["usd_per_ton"] / MT_TO_LB

LME.head()
# Out:
#             usd_per_ton  usd_per_lb
# DATE
# 1990-01-01  2365.556991    1.072999
# 1990-02-01  2358.943400    1.069999
# 1990-03-01  2625.702723    1.190999
# 1990-04-01  2685.226891    1.217998
# 1990-05-01  2740.342391    1.242998

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))

plt.plot(LME.index, LME["usd_per_lb"],
         label="LME", linewidth=1.4, color="steelblue")

plt.plot(SHFE.index, SHFE["usd_per_lb"],
         label="SHFE main", linewidth=1.1, color="red")
plt.plot(NY.index, NY["Close"],
         label="COMEX", linewidth=1.1, color="darkorange")

plt.title("Copper Prices: LME vs SHFE vs COMEX (USD per lb)")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
start_xlim = pd.Timestamp("2020-01-01")
end_xlim   = pd.Timestamp("2025-07-19")
plt.xlim(start_xlim, end_xlim)  
plt.show()

# %% [markdown]
# ## Appendix: Summary of the three exchanges

# %% [markdown]
# | Exchange (venue code)                       | Contract unit        | Price quote   | Typical trading hours (local)         | Warehouse/delivery system                                   | Tick size                                                      |
# | ------------------------------------------- | -------------------- | ------------- | ------------------------------------- | ----------------------------------------------------------- | -------------------------------------------------------------- |
# | **London Metal Exchange – LME Copper (CA)** | 25 metric tonnes     | USD per tonne | 01:00-19:00 London (ring + LMEselect) | Global LME-approved sheds; *“warrants”* transferable        | USD 0.10/tonne ([Lme][1])                                      |
# | **Shanghai Futures Exchange – SHFE 铜 (CU)** | 5 t                  | CNY per ton   | 09:00-15:00 & 21:00-02:00 Beijing     | Mainland China warehouses; VAT & import‐quota rules apply   | ¥10/ton (≈USD 1.4) ([tsite.shfe.com.cn][2], [Barchart.com][3]) |
# | **CME Group / COMEX Copper (HG)**           | 25 000 lb (≈11.34 t) | USD ¢ per lb  | 18:00-17:00 ET (electronically)       | U.S. COMEX-licensed warehouses; deliverable Grade 1 cathode | USD 0.0005/lb ([CME Group][4], [CME Group][5])                 |
#
# [1]: https://www.lme.com/en/metals/non-ferrous/lme-copper/contract-specifications?utm_source=chatgpt.com "Contract specifications | London Metal Exchange"
# [2]: https://tsite.shfe.com.cn/eng/market/futures/metal/cu/index.html?utm_source=chatgpt.com "Copper"
# [3]: https://www.barchart.com/futures/quotes/VC%2A0/profile?utm_source=chatgpt.com "SHFE Copper Aug '25 Futures Contract Specifications - Barchart.com"
# [4]: https://www.cmegroup.com/markets/metals/base/copper.contractSpecs.html?utm_source=chatgpt.com "Copper Futures Contract Specs - CME Group"
# [5]: https://www.cmegroup.com/markets/metals/base/copper.html?utm_source=chatgpt.com "Copper Futures Overview - CME Group"

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# --- Prepare lagged features for all available COMEX dates (including future) ---
# Use NY['Close'] for all available dates
comex_df = NY[['Close']].copy()
for lag in range(1, 6):
    comex_df[f'lag_{lag}'] = comex_df['Close'].shift(lag)

# Drop rows with NaN values due to lagging (for training)
train_df = comex_df.dropna().copy()

# Features and target for training (5 lags)
X_train = train_df[[f'lag_{i}' for i in range(1, 6)]]
y_train = train_df['Close']

# Fit Random Forest with reduced complexity to avoid overfitting
rf = RandomForestRegressor(n_estimators=15, max_depth=5, random_state=42)
rf.fit(X_train, y_train)

# --- Recursive rolling window prediction for all future dates ---
# Start with the last 5 actual prices from the end of available data
all_dates = comex_df.index
last_known_idx = np.where(~comex_df['Close'].isna())[0][-1]
# Build rolling window from last 5 known closes
rolling_window = list(comex_df['Close'].iloc[last_known_idx-4:last_known_idx+1])

# Predict forward from the first missing value (if any)
preds = []
pred_indices = []
for i in range(last_known_idx+1, len(comex_df)):
    features = np.array(rolling_window[-5:]).reshape(1, -1)
    pred = rf.predict(features)[0]
    preds.append(pred)
    pred_indices.append(i)
    rolling_window.append(pred)

# Insert predictions into comex_df
comex_df_pred = comex_df.copy()
for idx, pred in zip(pred_indices, preds):
    comex_df_pred.iloc[idx, comex_df_pred.columns.get_loc('Close')] = pred

# Plot actual and predicted COMEX prices for the full range
plt.figure(figsize=(14, 6))
plt.plot(comex_df.index, NY['Close'], label='Actual COMEX Close', color='blue', alpha=0.6)
if preds:
    plt.plot(comex_df.index[pred_indices], preds, label='Predicted COMEX Close (future)', color='orange', marker='o', alpha=0.8)
plt.title('Random Forest Prediction of COMEX Copper Prices (Rolling Window, All Dates)')
plt.xlabel('Date')
plt.ylabel('Price (USD/lb)')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# Optionally, print the last few predicted values
if preds:
    print('Last 5 predicted COMEX prices:')
    for d, p in zip(comex_df.index[pred_indices][-5:], preds[-5:]):
        print(f'{d.date()}: {p:.4f}')
# Out:
# /opt/miniconda3/envs/cosmos/lib/python3.12/site-packages/sklearn/base.py:1363: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
from sklearn.metrics import mean_squared_error, r2_score
import ipywidgets as widgets
from ipywidgets import interact

# Only compare on the historical period (where actual prices are available)
actual = comex_df['Close'].iloc[5:last_known_idx+1]
predicted = rf.predict(comex_df[[f'lag_{i}' for i in range(1, 6)]].iloc[5:last_known_idx+1])

rmse = np.sqrt(mean_squared_error(actual, predicted))
r2 = r2_score(actual, predicted)
print(f'Historical RMSE: {rmse:.4f}')
print(f'Historical R^2: {r2:.4f}')

# Visualization: Actual vs Predicted for historical period
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 6))
plt.plot(actual.index, actual, label='Actual COMEX Close', color='blue')
plt.plot(actual.index, predicted, label='Predicted COMEX Close', color='orange')
plt.title('Random Forest Prediction vs Actual (Historical)')
plt.xlabel('Date')
plt.ylabel('Price (USD/lb)')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# Interactive widget to inspect predictions
results_df = comex_df[['Close']].iloc[5:last_known_idx+1].copy()
results_df['Predicted'] = predicted
def show_prediction(idx):
    date = results_df.index[idx]
    actual = results_df.iloc[idx]['Close']
    pred = results_df.iloc[idx]['Predicted']
    print(f"Date: {date.strftime('%Y-%m-%d')}")
    print(f"Actual:    {actual:.4f}")
    print(f"Predicted: {pred:.4f}")

interact(show_prediction, idx=widgets.IntSlider(min=0, max=len(results_df)-1, step=1, value=0, description='Index'))
# Out:
# Historical RMSE: 0.0517
# Historical R^2: 0.9949
# interactive(children=(IntSlider(value=0, description='Index', max=3899), Output()), _dom_classes=('widget-inte…
# <function __main__.show_prediction(idx)>
